# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Часть 1. Python

# %%
#Напишите функцию, которая вычленяет из текста все числа и возвражает их списком

def take_numb(my_string):
  #Your code here
    lis = ''.join([c for c in my_string if c.isalnum() or c.isspace()]).split()
    num_list = [int(num) for num in filter(lambda num: num.isnumeric() , lis)]
    return print(num_list)


take_numb('I was born in 1998')  #[1998]
take_numb('She had got 5 cats and 3 kittens') #[5, 3]
take_numb('Does it really cost 500$? Or maybe 450$?') #[500, 450]
# Out:
# [1998]
# [5, 3]
# [500, 450]

# %%
#Напишите функцию, которая принимает на вход словарь, а возвращает все уникальные значения словаря списком

def get_distinct_dic(dic):
  #Your code here
    orig_list = list(set([int(num) for num in dic.values()])) 
    return orig_list
    
    

get_distinct_dic({'jan':47, 'feb':52, 'march':47, 'April':44, 'May':52, 'June':53, 'july':54, 'Aug':44, 'Sept':54}) # [47, 52, 44, 53, 54]
# Out:
# [52, 44, 53, 54, 47]

# %%
#Напишите функцию, которая принимает на вход список, а возвращает все уникальные 
#значения списка + печатает минимум и максимум списка

def get_distinct_list(dic):
  #Your code here
    dic.sort()
    return list(set(dic)), dic[0], dic[-1] 

get_distinct_list([9123, 31, 1938, 9123, 1, 249, 912, 10, 31, 213, 81, 10]) # [31, 1938, 9123, 1, 249, 912, 010, 213, 81], min = 1, max = 9123
# Out:
# ([1, 9123, 10, 912, 81, 1938, 213, 249, 31], 1, 9123)

# %%
#Выведите сколько раз в тексте встречается каждое слово (не учитывая регистр), каждый знак преминания и каждая буква

sample_test = "Гостиная Анны Павловны начала понемногу наполняться. Приехала высшая знать Петербурга, люди самые разнородные по возрастам и характерам, но одинаковые по обществу, в каком все жили; приехала дочь князя Василия, красавица Элен, заехавшая за отцом, чтобы с ним вместе ехать на праздник посланника. Она была в шифре и бальном платье. Приехала и известная, как la femme la plus séduisante de Pétersbourg 1, молодая, маленькая княгиня Болконская, прошлую зиму вышедшая замуж и теперь не выезжавшая в большой свет по причине своей беременности, но ездившая еще на небольшие вечера. Приехал князь Ипполит, сын князя Василия, с Мортемаром, которого он представил; приехал и аббат Морио и многие другие. — Вы не видали еще, — или: — вы не знакомы с ma tante? 2 — говорила Анна Павловна приезжавшим гостям и весьма серьезно подводила их к маленькой старушке в высоких бантах, выплывшей из другой комнаты, как скоро стали приезжать гости, называла их по имени, медленно переводя глаза с гостя на ma tante, и потом отходила. Все гости совершали обряд приветствования никому не известной, никому не интересной и не нужной тетушки. Анна Павловна с грустным, торжественным участием следила за их приветствиями, молчаливо одобряя их. Ma tante каждому говорила в одних и тех же выражениях о его здоровье, о своем здоровье и о здоровье ее величества, которое нынче было, слава Богу, лучше. Все подходившие, из приличия не выказывая поспешности, с чувством облегчения исполненной тяжелой обязанности отходили от старушки, чтоб уж весь вечер ни разу не подойти к ней. Молодая княгиня Болконская приехала с работой в шитом золотом бархатном мешке. Ее хорошенькая, с чуть черневшимися усиками верхняя губка была коротка по зубам, но тем милее она открывалась и тем еще милее вытягивалась иногда и опускалась на нижнюю. Как это бывает у вполне привлекательных женщин, недостаток ее — короткость губы и полуоткрытый рот — казались ее особенною, собственно ее красотой. Всем было весело смотреть на эту полную здоровья и живости хорошенькую будущую мать, так легко переносившую свое положение. Старикам и скучающим, мрачным молодым людям казалось, что они сами делаются похожи на нее, побыв и поговорив несколько времени с ней. Кто говорил с ней и видел при каждом слове ее светлую улыбочку и блестящие белые зубы, которые виднелись беспрестанно, тот думал, что он особенно нынче любезен. И это думал каждый."
arra = sample_test.lower()

#считаю сколько раз встречаются буквы и знаки
d_1 = dict((i, arra.count(i)) for i in set(list(arra)))

#считаю сколько раз встречаются слова
array = ''.join([c for c in arra if c.isalnum() or c.isspace()]).split()
d = dict((x, array.count(x)) for x in set(array))

#for i in set(array):
#    print('слово '+ i + ' встречается ' + str(d[i]) )
for i in set(arra):
    print('символ ' + i +  ' встречается ' +str(d_1[i]) )
#print(d)
#print(d_1)
# Out:
# символ ь встречается 34
# символ й встречается 18
# символ   встречается 369
# символ б встречается 39
# символ l встречается 3
# символ в встречается 94
# символ b встречается 1
# символ e встречается 8
# символ ч встречается 23
# символ o встречается 1
# символ 1 встречается 1
# символ я встречается 48
# символ t встречается 8
# символ r встречается 2
# символ g встречается 1
# символ p встречается 2
# символ s встречается 4
# символ и встречается 139
# символ у встречается 44
# символ ю встречается 14
# символ о встречается 201
# символ : встречается 1
# символ i встречается 1
# символ ; встречается 2
# символ л встречается 89
# символ а встречается 154
# символ . встречается 17
# символ з встречается 37
# символ п встречается 52
# символ ы встречается 44
# символ т встречается 96
# символ р встречается 77
# символ ? встречается 1
# символ d встречается 2
# символ н встречается 131
# символ д встречается 43
# символ ф встречается 1
# символ ш встречается 25
# ...

# %% [markdown]
# # Часть 2. Numpy

# %%
#Реализуйте функции, которые будут считать следующие расстояние между векторами:
a = np.array((9,4,8))
b = np.array((3,4,0))

#1. Евклидово расстояние
def evklid_dist(arr_a,arr_b):
    assert len(arr_a) == len(arr_b)
    
    dist = np.sqrt(np.sum((arr_a-arr_b)**2))
    return dist



#2. Хеммингово расстояние
def hamming_dist(arr_a, arr_b):
    assert len(arr_a) == len(arr_b)
    
    dist = sum([abs(arr_a[i] - arr_b[i]) for i in range(len(arr_b))])
    return dist



#3. Расстояние Чебышева
def cheb_dist(arr_a, arr_b):
    assert len(arr_a) == len(arr_b)
    
    dist = max([abs(arr_a[i] - arr_b[i]) for i in range(len(arr_b))])
    return dist


print(evklid_dist(a,b))
print(hamming_dist(a,b))
print(cheb_dist(a,b))
# Вектора в функцию подаются как numpy.array.
# Out:
# 10.0
# 14
# 8

# %% [markdown]
# # Часть 3. Pandas

# %%
#Считайте датасет из файла train.csv - это данные о выживаемости на Титанике
df = pd.read_csv("train.csv")
#df.Name.head(100)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
#Выведите основную информацию о датасете - число пропусков, средние значения и т.д. 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Посчитайте процент выживаемости у каждого класса пассажиров (Pclass) 
pr= df.groupby('Pclass').Survived.sum()* 100 / df.groupby('Pclass').Survived.count()
#pr[3]

print('1-ом классе = ' '%.3f' % float(pr[1]) )
print('2-ом классе = ' '%.3f' % float(pr[2]) )
print('3-ем классе = ' '%.3f' % float(pr[3]) )
# Out:
# 1-ом классе = 62.963
# 2-ом классе = 47.283
# 3-ем классе = 24.236

# %%
#Посчитайте процнт выживаемости для мужчин и женщин
proc = df.groupby('Sex').Survived.sum() * 100 / df.groupby('Sex').Survived.count()

print('Мужчин = ' '%.3f' % float(proc[1]) )
print('Женщин = ' '%.3f' % float(proc[0]) )
# Out:
# Мужчин = 18.891
# Женщин = 74.204

# %%
#Выведите самое популярное мужское и самое популярное женское имя на корабле
df.Sal = df['Name'].apply(lambda name: name.split(',')[1].split('.')[0].strip())

df['man'] = df.loc[df['Sex'] == 'male' ]['Name'].apply(lambda s: s.split('.')[1].split(' ')[1]) 
df['man'].value_counts()

df.mrs = df.loc[df.Sal.isin(['Mrs'])]['Name'].apply(lambda s: s.split('.')[1])
df.mrs.values

#arr_n = df.mrs.values
#arr = [i for i in arr_n if len(i) > 1 ]
#arr
#df.mrs


#d = dict((x, arr.count(x)) for x in set(list(arr)) if arr.count(x)> 2)
#print(d)
#df.groupby('Pclass').
# Out:
# array([' John Bradley (Florence Briggs Thayer)',
#        ' Jacques Heath (Lily May Peel)',
#        ' Oscar W (Elisabeth Vilhelmina Berg)', ' Nicholas (Adele Achem)',
#        ' (Mary D Kingcome) ', ' Julius (Emelia Maria Vandemoortele)',
#        ' Fatima', ' Carl Oscar (Selma Augusta Emilia Johansson)',
#        ' William Augustus (Marie Eugenie)',
#        ' Johan (Johanna Persdotter Larsson)',
#        ' William John Robert (Dorothy Ann Wonnacott)',
#        ' Josef (Josefine Franchi)', ' Henry Sleeper (Myna Haxtun)',
#        ' Lizzie (Elizabeth Anne Wilkinson)', ' (Elizabeth Ramell)',
#        ' Karl Alfred (Maria Mathilda Gustafsson)',
#        ' John T (Ada Julia Bone)', ' Alexander A (Grace Charity Laury)',
#        ' Leopold (Mathilde Francoise Pede)', ' Joseph (Sultana)',
#        ' Pekka Pietari (Elin Matilda Dolck)', ' Thomas (Edith Wearne)',
#        ' James (Elizabeth "Bessie" Inglis Milne)',
# ...

# %%
#Выведите самое популярное мужское и самое популярное женское имя на корабле в каждом классе

# %%
#Выведите количества n-местных кабин (в которых было 2, 3, 4, ... человека)

arr_cab = df.Cabin.values
arr = [i for i in arr_cab if i is not np.nan]                      # убираю все nan из массива
d = dict((x, arr.count(x)) for x in set(arr) if arr.count(x) > 1)
arr_l = list(d.values())
dic = dict((x, arr_l.count(x)) for x in set(arr_l))
#arr.value_counts()

print(dic)
# Out:
# {2: 38, 3: 5, 4: 3}

# %%
#Выведите часть таблицы с пассажирами, возраст которых больше 44 лет.
df.loc[df.Age > 44]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 92            93         0       1
# 94            95         0       3
# 96            97         0       1
# 110          111         0       1
# 116          117         0       3
# 124          125         0       1
# 129          130         0       3
# 132          133         0       3
# 150          151         0       2
# 152          153         0       3
# 155          156         0       1
# 167          168         0       3
# 170          171         0       1
# 174          175         0       1
# 177          178         0       1
# 187          188         1       1
# 195          196         1       1
# 203          204         0       3
# ...

# %%
#Выведите часть таблицы с пассажирами, возраст которых меньше 44 лет и которые мужского пола.
df.loc[(df.Sex == 'male') & (df.Age < 44)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# 23            24         1       1             Sloper, Mr. William Thompson
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 30            31         0       1                 Uruchurtu, Don. Manuel E
# ...

# %% [markdown]
# # Часть 4. Визуализация
# ### Вопросы по данным из датасета df, который использовался на воркшопе по визуализации.

# %%
import glob
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

from plotly.subplots import make_subplots

# %%
paths_to_data = glob.glob('./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/*')
paths_to_data.remove('./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/README.md')

# %%
df = pd.DataFrame()

for i in tqdm(range(len(paths_to_data))):
    tmp = pd.read_csv(paths_to_data[i])
    df = df.append(tmp)
# Out:
#   1%|          | 2/264 [00:01<02:54,  1.50it/s]/home/azamat/bexugurov/bexugurov/lib/python3.5/site-packages/pandas/core/frame.py:6692: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# 100%|██████████| 264/264 [02:24<00:00,  1.83it/s]

# %%
df.head()
df['Last_Update'].fillna(df['Last Update'], inplace=True)
df.head()
# Out:
#     Active Admin2  Case-Fatality_Ratio Combined_Key  Confirmed Country/Region  \
# 0   8305.0    NaN             3.650076  Afghanistan    38054.0            NaN
# 1   3938.0    NaN             2.951772      Albania     8605.0            NaN
# 2  11043.0    NaN             3.454537      Algeria    41858.0            NaN
# 3    130.0    NaN             5.000000      Andorra     1060.0            NaN
# 4   1245.0    NaN             4.500450       Angola     2222.0            NaN
#
#   Country_Region  Deaths  FIPS  Incidence_Rate Last Update  \
# 0    Afghanistan  1389.0   NaN       97.753973         NaN
# 1        Albania   254.0   NaN      299.013135         NaN
# 2        Algeria  1446.0   NaN       95.454970         NaN
# 3        Andorra    53.0   NaN     1371.901896         NaN
# 4         Angola   100.0   NaN        6.760731         NaN
#
#            Last_Update       Lat  Latitude      Long_  Longitude  \
# 0  2020-08-25 04:28:02  33.93911       NaN  67.709953        NaN
# ...

# %% [markdown]
# Создайте признак 'date', в котором будет храниться дата (гггг-мм-дд). Постройте график зависимости количества строк от даты в этих строках. Найдите минимальное количество строк за день в датасете за период с 01.04.2020 по 31.08.2020.
#
# Варианты:
# - 1990
# - 2472
# - 472
# - 103
# - 1984

# %%
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

df['date'] = pd.to_datetime(df['Last_Update']).apply(lambda x: x.date())
df['date'].value_counts().sort_index().plot()

mon_start = pd.to_datetime('42020', format='%m%Y').date()
mon_end = pd.to_datetime('3182020',format='%d%m%Y').date()

sec_df = df.loc[(df.date > mon_start) & (df.date < mon_end)]
min_m = sec_df.groupby('date').Last_Update.count().min()
print(min_m)
#df.date
# Out:
# 103

# %% [markdown]
# Найдите максимальное количество строк за день в датасете за период с 01.04.2020 по 31.08.2020.
#
# Варианты:
# - 3990
# - 3952
# - 2472
# - 5120
# - 7025

# %%
print(sec_df.groupby('date').Last_Update.count().max())
# Out:
# 4062

# %% [markdown]
# Постройте подобный график только для России. С какого числа Россия начала предоставлять информацию в разбивке по областям?
#
# Варианты:
# - 01.04.2020
# - 06.04.2020
# - 31.05.2020
# - 01.06.2020
# - 02.06.2020

# %%
df['Province_State'].fillna(df['Province/State'], inplace=True)
df['Country_Region'].fillna(df['Country/Region'], inplace=True)
#df[df['Country_Region'].str.startswith('R')]['Country_Region'].unique()

df_rus = df.loc[df.Country_Region.isin(['Russia','Russian Federation'])]
df_rus['date'].value_counts().sort_index().plot()

df_rus.groupby('Province_State').date.min()[0]
# Out:
# datetime.date(2020, 6, 2)

# %% [markdown]
# Постройте гистограмму ежедневного прироста подтверждённых случаев заболевания.
# Когда в России был первый пик заболеваемости?
#
# Варианты:
# - 03.04.2020
# - 19.04.2020
# - 06.05.2020
# - 12.05.2020
# - 07.06.2020

# %%
#df.groupby('date').Confirmed.sum()#.hist()
# Out:
# date
# 2020-01-22         555.0
# 2020-01-23         653.0
# 2020-01-24         941.0
# 2020-01-25        1438.0
# 2020-01-26        2118.0
# 2020-01-27        2927.0
# 2020-01-28        5578.0
# 2020-01-29        6165.0
# 2020-01-30        8235.0
# 2020-01-31       10151.0
# 2020-02-01       12287.0
# 2020-02-02       16804.0
# 2020-02-03       19902.0
# 2020-02-04       24027.0
# 2020-02-05       27587.0
# 2020-02-06       30798.0
# 2020-02-07       34485.0
# 2020-02-08       37078.0
# 2020-02-09       40326.0
# 2020-02-10       42696.0
# 2020-02-11       44584.0
# 2020-02-12       45590.0
# 2020-02-13       60636.0
# 2020-02-14       66634.0
# 2020-02-15       69112.0
# 2020-02-16       71197.0
# 2020-02-17       73273.0
# 2020-02-18       75029.0
# 2020-02-19       75634.0
# 2020-02-20       77227.0
#                  ...
# 2020-09-13    28760767.0
# 2020-09-14    28996626.0
# 2020-09-15    29192698.0
# 2020-09-16    29560112.0
# 2020-09-17    29864506.0
# ...

# %%
df.shape
# Out:
# (749015, 20)

# %% [markdown]
# Постройте гистограммы подтверждённых случаев заболеваний в России и Бразилии, чтобы выбрать правильный ответ.
#
# Варианты:
# - В июле и августе ежедневное количество подтверждённых случаев заражения в Бразилии всегда выше, чем в России.
# - В летние месяцы ежедневное количество подтверждённых случаев заражения в Бразилии впервые превзошло такой же показатель в России.
# - В России более заметна недельная сезонность регистрации заболеваемости.
# - В летние месяцы отсутствуют данные за несколько дней в обеих странах.
# - Ни один ответ не верен.

# %%
df[df['Country_Region'].str.startswith('B')]['Country_Region'].unique()
# Out:
# array(['Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burma', 'Burundi', 'Bahamas, The'],
#       dtype=object)
